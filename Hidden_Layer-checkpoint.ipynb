# %%
##########################
# 라이브러리 사용
import tensorflow as tf
import pandas as pd
 
###########################
# 1.과거의 데이터를 준비합니다.
파일경로 = 'https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/boston.csv'
보스턴 = pd.read_csv(파일경로)
 
# 종속변수, 독립변수
독립 = 보스턴[['crim', 'zn', 'indus', 'chas', 'nox', 
            'rm', 'age', 'dis', 'rad', 'tax',
            'ptratio', 'b', 'lstat']]
종속 = 보스턴[['medv']]
print(독립.shape, 종속.shape)
# Out:
# (506, 13) (506, 1)

# %%
# 2. 모델의 구조를 만듭니다
X = tf.keras.layers.Input(shape=[13])
H = tf.keras.layers.Dense(10, activation='swish')(X)#히든레이어 만들기 
H = tf.keras.layers.Dense(10, activation='swish')(H)#히든레이어 만들기 
H = tf.keras.layers.Dense(10, activation='swish')(H)#H히든레이어 만들기 

Y = tf.keras.layers.Dense(1)(H)#히든레이어 집어넣어주고 연결
model = tf.keras.models.Model(X, Y)
model.compile(loss='mse')
 
# 모델 구조 확인
model.summary()
# Out:
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_9 (InputLayer)        [(None, 13)]              0
#
#  dense_21 (Dense)            (None, 10)                140
#
#  dense_22 (Dense)            (None, 10)                110
#
#  dense_23 (Dense)            (None, 10)                110
#
#  dense_24 (Dense)            (None, 1)                 11
#
# ...
# Total params: 371
# Trainable params: 371
# Non-trainable params: 0
# _________________________________________________________________

# %%
###########################
# 3.데이터로 모델을 학습(FIT)합니다.
model.fit(독립, 종속, epochs=1000,verbose=0)
model.fit(독립, 종속, epochs=10)
# Out:
# Epoch 1/10
# 16/16 [==============================] - 0s 1ms/step - loss: 10.2669
# Epoch 2/10
# 16/16 [==============================] - 0s 2ms/step - loss: 10.7347
# Epoch 3/10
# 16/16 [==============================] - 0s 2ms/step - loss: 9.8537
# Epoch 4/10
# 16/16 [==============================] - 0s 1ms/step - loss: 10.3101
# Epoch 5/10
# 16/16 [==============================] - 0s 1ms/step - loss: 9.9443
# Epoch 6/10
# 16/16 [==============================] - 0s 2ms/step - loss: 10.2299
# Epoch 7/10
# 16/16 [==============================] - 0s 2ms/step - loss: 9.7698
# Epoch 8/10
# 16/16 [==============================] - 0s 2ms/step - loss: 11.1921
# Epoch 9/10
# 16/16 [==============================] - 0s 1ms/step - loss: 9.8079
# Epoch 10/10
# 16/16 [==============================] - 0s 1ms/step - loss: 10.6090

# %%
###########################
# 4. 모델을 이용합니다
print(model.predict(독립[:5]))
print(종속[:5])
 
###########################
# 모델의 수식 확인
print(model.get_weights())
# Out:
# [[28.2858  ]
#  [22.874828]
#  [29.379463]
#  [32.436005]
#  [29.97807 ]]
#    medv
# 0  24.0
# 1  21.6
# 2  34.7
# 3  33.4
# 4  36.2
# [array([[ 0.21387145,  0.14773746,  0.7584307 ,  0.43477723,  1.1116999 ,
#         -0.46083823,  0.42510086, -0.35185933,  0.7121272 , -0.67874026],
#        [ 0.280184  ,  0.10297264, -0.05279079,  0.39312428,  0.0810517 ,
#         -0.3030486 ,  0.05499691,  0.03823691,  0.14778668,  0.04809216],
#        [-0.14685848,  0.04021385, -0.538952  ,  0.36033866, -0.7729924 ,
#         -0.47379747,  0.43903583, -0.02581982, -0.2916436 , -0.19962208],
#        [ 0.29703963, -0.74721175, -0.38437724, -0.16905202,  1.1592538 ,
#         -0.14522138,  0.23536682,  1.3964051 , -0.7317517 , -0.82712144],
#        [-0.6288806 , -0.12461588, -0.50105137, -0.32275334, -0.09626514,
#         -0.15403998,  0.1656    , -0.0788343 ,  0.08582601,  0.49630016],
#        [-0.42634964,  0.506712  , -0.15738375, -0.39730334,  1.5830411 ,
# ...
